# %% [markdown]
# #### Model Model Model

# %% [markdown]
# Yes we model, But what. WHAT.
# Let's take the eg of Logistic Regression. You might say P(Y=k | X=x). But that's a mathematical equation. Intuitively, what are we modelling. Forget all the engineering and maths. In words, what are we modelling.
#
# ISLR Page: 138
#
# "*In statistical jargon, we model the conditional distirbution of the repsonse Y, given the predictior(s) X.*"
